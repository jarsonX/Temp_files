# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
df.ConvertedComp.plot.density(color='green')
plt.title('Salary distribution')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
plt.hist(df.ConvertedComp)
plt.title('Salary distribution')
plt.xlabel('Salary')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
df.ConvertedComp.median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
df.Gender.value_counts()['Man']
# Out:
# 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
df[df['Gender'] == 'Woman'].ConvertedComp.median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
age_min = df.Age.min()
age_1Q = df.Age.quantile(q=0.25)
age_2Q = df.Age.quantile(q=0.5)
age_3Q = df.Age.quantile(q=0.75)
age_max = df.Age.max()

print('Min: ', age_min, '\n', 
      '1Q: ', age_1Q, '\n',
      '2Q: ', age_2Q, '\n',
      '3Q: ', age_3Q, '\n',
      'Max: ', age_max, '\n',
      sep="")
# Out:
# Min: 16.0
# 1Q: 25.0
# 2Q: 29.0
# 3Q: 35.0
# Max: 99.0

# %%
#I followed the instructions but obviously the above could have been achieved much easier with describe()
df.Age.describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
plt.hist(df.Age)
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Age'].dropna(how='any', inplace=True)

# %%
df['Age'].isna().value_counts()
# Out:
# False    11111
# True       287
# Name: Age, dtype: int64

# %%
i = 0
for el in df.Age:
    print(i, el, type(el))
    i += 1
# Out:
# 0 22.0 <class 'float'>
# 1 23.0 <class 'float'>
# 2 28.0 <class 'float'>
# 3 26.0 <class 'float'>
# 4 29.0 <class 'float'>
# 5 31.0 <class 'float'>
# 6 38.0 <class 'float'>
# 7 47.0 <class 'float'>
# 8 22.0 <class 'float'>
# 9 23.0 <class 'float'>
# 10 22.0 <class 'float'>
# 11 34.0 <class 'float'>
# 12 32.0 <class 'float'>
# 13 21.0 <class 'float'>
# 14 44.0 <class 'float'>
# 15 42.0 <class 'float'>
# 16 27.0 <class 'float'>
# 17 43.0 <class 'float'>
# 18 34.0 <class 'float'>
# 19 23.0 <class 'float'>
# 20 18.0 <class 'float'>
# 21 37.0 <class 'float'>
# 22 33.0 <class 'float'>
# 23 31.0 <class 'float'>
# 24 27.0 <class 'float'>
# 25 34.0 <class 'float'>
# 26 19.0 <class 'float'>
# 27 24.0 <class 'float'>
# 28 29.0 <class 'float'>
# 29 42.0 <class 'float'>
# 30 21.0 <class 'float'>
# 31 24.0 <class 'float'>
# 32 27.0 <class 'float'>
# 33 32.0 <class 'float'>
# 34 25.0 <class 'float'>
# 35 24.0 <class 'float'>
# 36 22.0 <class 'float'>
# 37 26.0 <class 'float'>
# 38 26.0 <class 'float'>
# 39 36.0 <class 'float'>
# 40 25.0 <class 'float'>
# 41 35.0 <class 'float'>
# 42 27.0 <class 'float'>
# 43 30.0 <class 'float'>
# 44 25.0 <class 'float'>
# 45 39.0 <class 'float'>
# 46 37.0 <class 'float'>
# 47 29.0 <class 'float'>
# 48 41.0 <class 'float'>
# 49 26.0 <class 'float'>
# 50 54.0 <class 'float'>
# 51 26.0 <class 'float'>
# 52 21.0 <class 'float'>
# 53 31.0 <class 'float'>
# 54 38.0 <class 'float'>
# 55 26.0 <class 'float'>
# 56 28.0 <class 'float'>
# 57 26.0 <class 'float'>
# 58 27.0 <class 'float'>
# 59 32.0 <class 'float'>
# 60 30.0 <class 'float'>
# 61 34.0 <class 'float'>
# 62 23.0 <class 'float'>
# 63 32.0 <class 'float'>
# 64 24.0 <class 'float'>
# 65 25.0 <class 'float'>
# 66 47.0 <class 'float'>
# 67 nan <class 'float'>
# 68 28.0 <class 'float'>
# 69 34.0 <class 'float'>
# 70 34.0 <class 'float'>
# 71 25.0 <class 'float'>
# 72 29.0 <class 'float'>
# 73 35.0 <class 'float'>
# 74 32.0 <class 'float'>
# 75 47.0 <class 'float'>
# 76 30.0 <class 'float'>
# 77 31.0 <class 'float'>
# 78 24.0 <class 'float'>
# 79 31.0 <class 'float'>
# 80 22.0 <class 'float'>
# 81 35.0 <class 'float'>
# 82 29.0 <class 'float'>
# 83 30.0 <class 'float'>
# 84 29.0 <class 'float'>
# 85 28.0 <class 'float'>
# 86 28.0 <class 'float'>
# 87 27.0 <class 'float'>
# 88 27.0 <class 'float'>
# 89 28.0 <class 'float'>
# 90 29.0 <class 'float'>
# 91 40.0 <class 'float'>
# 92 35.0 <class 'float'>
# 93 45.0 <class 'float'>
# 94 34.0 <class 'float'>
# 95 33.0 <class 'float'>
# 96 30.0 <class 'float'>
# 97 30.0 <class 'float'>
# 98 41.0 <class 'float'>
# 99 35.0 <class 'float'>
# 100 36.0 <class 'float'>
# 101 39.0 <class 'float'>
# 102 nan <class 'float'>
# 103 23.0 <class 'float'>
# 104 28.0 <class 'float'>
# 105 33.0 <class 'float'>
# 106 31.0 <class 'float'>
# 107 32.0 <class 'float'>
# 108 45.0 <class 'float'>
# 109 31.0 <class 'float'>
# 110 32.0 <class 'float'>
# 111 35.0 <class 'float'>
# 112 33.0 <class 'float'>
# 113 33.0 <class 'float'>
# 114 24.0 <class 'float'>
# 115 27.0 <class 'float'>
# 116 28.0 <class 'float'>
# 117 41.0 <class 'float'>
# 118 31.0 <class 'float'>
# 119 27.0 <class 'float'>
# 120 24.0 <class 'float'>
# 121 25.0 <class 'float'>
# 122 24.0 <class 'float'>
# 123 29.0 <class 'float'>
# 124 34.0 <class 'float'>
# 125 29.0 <class 'float'>
# 126 29.0 <class 'float'>
# 127 27.0 <class 'float'>
# 128 47.0 <class 'float'>
# 129 26.0 <class 'float'>
# 130 32.0 <class 'float'>
# 131 23.0 <class 'float'>
# 132 37.0 <class 'float'>
# 133 27.0 <class 'float'>
# 134 31.0 <class 'float'>
# 135 39.0 <class 'float'>
# 136 33.0 <class 'float'>
# 137 30.0 <class 'float'>
# 138 28.0 <class 'float'>
# 139 51.0 <class 'float'>
# 140 36.0 <class 'float'>
# 141 32.0 <class 'float'>
# 142 24.0 <class 'float'>
# 143 31.0 <class 'float'>
# 144 22.0 <class 'float'>
# 145 24.0 <class 'float'>
# 146 30.0 <class 'float'>
# 147 32.0 <class 'float'>
# 148 23.0 <class 'float'>
# 149 34.0 <class 'float'>
# 150 34.0 <class 'float'>
# 151 31.0 <class 'float'>
# 152 47.0 <class 'float'>
# 153 35.0 <class 'float'>
# 154 24.0 <class 'float'>
# 155 33.0 <class 'float'>
# 156 30.0 <class 'float'>
# 157 30.0 <class 'float'>
# 158 28.0 <class 'float'>
# 159 35.0 <class 'float'>
# 160 23.0 <class 'float'>
# 161 33.0 <class 'float'>
# 162 25.0 <class 'float'>
# 163 26.0 <class 'float'>
# 164 25.0 <class 'float'>
# 165 29.0 <class 'float'>
# 166 33.0 <class 'float'>
# 167 40.0 <class 'float'>
# 168 25.0 <class 'float'>
# 169 37.0 <class 'float'>
# 170 26.0 <class 'float'>
# 171 57.0 <class 'float'>
# 172 32.0 <class 'float'>
# 173 26.0 <class 'float'>
# 174 38.0 <class 'float'>
# 175 28.0 <class 'float'>
# 176 27.0 <class 'float'>
# 177 38.0 <class 'float'>
# 178 52.0 <class 'float'>
# 179 30.0 <class 'float'>
# 180 41.0 <class 'float'>
# 181 22.0 <class 'float'>
# 182 48.0 <class 'float'>
# 183 31.0 <class 'float'>
# 184 49.0 <class 'float'>
# 185 27.0 <class 'float'>
# 186 30.0 <class 'float'>
# 187 24.0 <class 'float'>
# 188 32.0 <class 'float'>
# 189 43.0 <class 'float'>
# 190 33.0 <class 'float'>
# 191 35.0 <class 'float'>
# 192 44.0 <class 'float'>
# 193 21.0 <class 'float'>
# 194 27.0 <class 'float'>
# 195 28.0 <class 'float'>
# 196 29.0 <class 'float'>
# 197 32.0 <class 'float'>
# 198 28.0 <class 'float'>
# 199 51.0 <class 'float'>
# 200 24.0 <class 'float'>
# 201 41.0 <class 'float'>
# 202 24.0 <class 'float'>
# 203 38.0 <class 'float'>
# 204 25.0 <class 'float'>
# 205 23.0 <class 'float'>
# 206 28.0 <class 'float'>
# 207 31.0 <class 'float'>
# 208 29.0 <class 'float'>
# 209 24.0 <class 'float'>
# 210 35.0 <class 'float'>
# 211 39.0 <class 'float'>
# 212 32.0 <class 'float'>
# 213 37.0 <class 'float'>
# 214 29.0 <class 'float'>
# 215 23.0 <class 'float'>
# 216 23.0 <class 'float'>
# 217 28.0 <class 'float'>
# 218 26.0 <class 'float'>
# 219 30.0 <class 'float'>
# 220 29.0 <class 'float'>
# 221 46.0 <class 'float'>
# 222 22.0 <class 'float'>
# 223 31.0 <class 'float'>
# 224 32.0 <class 'float'>
# 225 41.0 <class 'float'>
# 226 25.0 <class 'float'>
# 227 27.0 <class 'float'>
# 228 27.0 <class 'float'>
# 229 37.0 <class 'float'>
# 230 23.0 <class 'float'>
# 231 24.0 <class 'float'>
# 232 31.0 <class 'float'>
# 233 32.0 <class 'float'>
# 234 29.0 <class 'float'>
# 235 20.0 <class 'float'>
# 236 30.0 <class 'float'>
# 237 40.0 <class 'float'>
# 238 23.0 <class 'float'>
# 239 30.0 <class 'float'>
# 240 24.0 <class 'float'>
# 241 25.0 <class 'float'>
# 242 37.0 <class 'float'>
# 243 42.0 <class 'float'>
# 244 25.0 <class 'float'>
# 245 24.0 <class 'float'>
# 246 36.0 <class 'float'>
# 247 24.0 <class 'float'>
# 248 23.0 <class 'float'>
# 249 35.0 <class 'float'>
# 250 35.0 <class 'float'>
# 251 20.0 <class 'float'>
# 252 40.0 <class 'float'>
# 253 30.0 <class 'float'>
# 254 21.0 <class 'float'>
# 255 30.0 <class 'float'>
# 256 28.0 <class 'float'>
# 257 28.0 <class 'float'>
# 258 27.0 <class 'float'>
# 259 24.0 <class 'float'>
# 260 23.0 <class 'float'>
# 261 nan <class 'float'>
# 262 30.0 <class 'float'>
# 263 nan <class 'float'>
# 264 24.0 <class 'float'>
# 265 25.0 <class 'float'>
# 266 29.0 <class 'float'>
# 267 23.0 <class 'float'>
# 268 nan <class 'float'>
# 269 41.0 <class 'float'>
# 270 31.0 <class 'float'>
# 271 43.0 <class 'float'>
# 272 29.0 <class 'float'>
# 273 29.0 <class 'float'>
# 274 28.0 <class 'float'>
# 275 34.0 <class 'float'>
# 276 34.0 <class 'float'>
# 277 29.0 <class 'float'>
# 278 27.0 <class 'float'>
# 279 30.0 <class 'float'>
# 280 33.0 <class 'float'>
# 281 nan <class 'float'>
# 282 24.0 <class 'float'>
# 283 36.0 <class 'float'>
# 284 39.0 <class 'float'>
# 285 30.0 <class 'float'>
# 286 23.0 <class 'float'>
# 287 24.0 <class 'float'>
# 288 37.0 <class 'float'>
# 289 37.0 <class 'float'>
# 290 28.0 <class 'float'>
# 291 28.0 <class 'float'>
# 292 35.0 <class 'float'>
# 293 27.0 <class 'float'>
# 294 31.0 <class 'float'>
# 295 30.0 <class 'float'>
# 296 52.0 <class 'float'>
# 297 33.0 <class 'float'>
# 298 36.0 <class 'float'>
# 299 27.0 <class 'float'>
# 300 23.0 <class 'float'>
# 301 28.0 <class 'float'>
# 302 29.0 <class 'float'>
# 303 18.0 <class 'float'>
# 304 28.0 <class 'float'>
# 305 31.0 <class 'float'>
# 306 27.0 <class 'float'>
# 307 36.0 <class 'float'>
# 308 24.0 <class 'float'>
# 309 23.0 <class 'float'>
# 310 29.0 <class 'float'>
# 311 37.0 <class 'float'>
# 312 19.0 <class 'float'>
# 313 24.0 <class 'float'>
# 314 28.0 <class 'float'>
# 315 33.0 <class 'float'>
# 316 37.0 <class 'float'>
# 317 25.0 <class 'float'>
# 318 28.0 <class 'float'>
# 319 35.0 <class 'float'>
# 320 28.0 <class 'float'>
# 321 29.0 <class 'float'>
# 322 34.0 <class 'float'>
# 323 32.0 <class 'float'>
# 324 24.0 <class 'float'>
# 325 36.0 <class 'float'>
# 326 28.0 <class 'float'>
# 327 22.0 <class 'float'>
# 328 41.0 <class 'float'>
# 329 35.0 <class 'float'>
# 330 34.0 <class 'float'>
# 331 36.0 <class 'float'>
# 332 39.0 <class 'float'>
# 333 49.0 <class 'float'>
# 334 36.0 <class 'float'>
# 335 24.0 <class 'float'>
# 336 25.0 <class 'float'>
# 337 33.0 <class 'float'>
# 338 29.0 <class 'float'>
# 339 22.0 <class 'float'>
# 340 19.0 <class 'float'>
# 341 26.0 <class 'float'>
# 342 38.0 <class 'float'>
# 343 32.0 <class 'float'>
# 344 34.0 <class 'float'>
# 345 32.0 <class 'float'>
# 346 34.0 <class 'float'>
# 347 27.0 <class 'float'>
# 348 27.0 <class 'float'>
# 349 28.0 <class 'float'>
# 350 31.0 <class 'float'>
# 351 42.0 <class 'float'>
# 352 28.0 <class 'float'>
# 353 45.0 <class 'float'>
# 354 33.0 <class 'float'>
# 355 27.0 <class 'float'>
# 356 34.0 <class 'float'>
# 357 24.0 <class 'float'>
# 358 29.0 <class 'float'>
# 359 27.0 <class 'float'>
# 360 21.0 <class 'float'>
# 361 26.0 <class 'float'>
# 362 31.0 <class 'float'>
# 363 45.0 <class 'float'>
# 364 24.0 <class 'float'>
# 365 24.0 <class 'float'>
# 366 29.0 <class 'float'>
# 367 37.0 <class 'float'>
# 368 26.0 <class 'float'>
# 369 29.0 <class 'float'>
# 370 31.0 <class 'float'>
# 371 24.0 <class 'float'>
# 372 22.0 <class 'float'>
# 373 36.0 <class 'float'>
# 374 21.0 <class 'float'>
# 375 30.0 <class 'float'>
# 376 27.0 <class 'float'>
# 377 41.0 <class 'float'>
# 378 24.0 <class 'float'>
# 379 37.0 <class 'float'>
# 380 23.0 <class 'float'>
# 381 nan <class 'float'>
# 382 28.0 <class 'float'>
# 383 32.0 <class 'float'>
# 384 36.0 <class 'float'>
# 385 30.0 <class 'float'>
# 386 21.0 <class 'float'>
# 387 21.0 <class 'float'>
# 388 44.0 <class 'float'>
# 389 27.0 <class 'float'>
# 390 27.0 <class 'float'>
# 391 44.0 <class 'float'>
# 392 22.0 <class 'float'>
# 393 26.0 <class 'float'>
# 394 36.0 <class 'float'>
# 395 26.0 <class 'float'>
# 396 23.0 <class 'float'>
# 397 30.0 <class 'float'>
# 398 24.0 <class 'float'>
# 399 27.0 <class 'float'>
# 400 25.0 <class 'float'>
# 401 27.0 <class 'float'>
# 402 30.0 <class 'float'>
# 403 25.0 <class 'float'>
# 404 23.0 <class 'float'>
# 405 32.0 <class 'float'>
# 406 23.0 <class 'float'>
# 407 25.0 <class 'float'>
# 408 32.0 <class 'float'>
# 409 30.0 <class 'float'>
# 410 20.0 <class 'float'>
# 411 46.0 <class 'float'>
# 412 28.0 <class 'float'>
# 413 23.0 <class 'float'>
# 414 28.0 <class 'float'>
# 415 22.0 <class 'float'>
# 416 nan <class 'float'>
# 417 21.0 <class 'float'>
# 418 25.0 <class 'float'>
# 419 28.0 <class 'float'>
# 420 26.0 <class 'float'>
# 421 25.0 <class 'float'>
# 422 25.0 <class 'float'>
# 423 28.0 <class 'float'>
# 424 25.0 <class 'float'>
# 425 20.0 <class 'float'>
# 426 51.0 <class 'float'>
# 427 38.0 <class 'float'>
# 428 41.0 <class 'float'>
# 429 33.0 <class 'float'>
# 430 20.0 <class 'float'>
# 431 32.0 <class 'float'>
# 432 28.0 <class 'float'>
# 433 28.0 <class 'float'>
# 434 31.0 <class 'float'>
# 435 20.0 <class 'float'>
# 436 22.0 <class 'float'>
# 437 32.0 <class 'float'>
# 438 33.0 <class 'float'>
# 439 34.0 <class 'float'>
# 440 27.0 <class 'float'>
# 441 38.0 <class 'float'>
# 442 31.0 <class 'float'>
# 443 22.0 <class 'float'>
# 444 28.0 <class 'float'>
# 445 27.0 <class 'float'>
# 446 32.0 <class 'float'>
# 447 24.0 <class 'float'>
# 448 42.0 <class 'float'>
# 449 38.0 <class 'float'>
# 450 23.0 <class 'float'>
# 451 40.0 <class 'float'>
# 452 26.0 <class 'float'>
# 453 28.0 <class 'float'>
# 454 35.0 <class 'float'>
# 455 29.0 <class 'float'>
# 456 22.0 <class 'float'>
# 457 36.0 <class 'float'>
# 458 53.0 <class 'float'>
# 459 22.0 <class 'float'>
# 460 28.0 <class 'float'>
# 461 45.0 <class 'float'>
# 462 27.0 <class 'float'>
# 463 40.0 <class 'float'>
# 464 35.0 <class 'float'>
# 465 29.0 <class 'float'>
# 466 20.0 <class 'float'>
# 467 36.0 <class 'float'>
# 468 25.0 <class 'float'>
# 469 25.0 <class 'float'>
# 470 25.0 <class 'float'>
# 471 27.0 <class 'float'>
# 472 26.0 <class 'float'>
# 473 27.0 <class 'float'>
# 474 26.0 <class 'float'>
# 475 nan <class 'float'>
# 476 32.0 <class 'float'>
# 477 25.0 <class 'float'>
# 478 27.0 <class 'float'>
# 479 24.0 <class 'float'>
# 480 29.0 <class 'float'>
# 481 26.0 <class 'float'>
# 482 34.0 <class 'float'>
# 483 29.0 <class 'float'>
# 484 50.0 <class 'float'>
# 485 26.0 <class 'float'>
# 486 43.0 <class 'float'>
# 487 40.0 <class 'float'>
# 488 31.0 <class 'float'>
# 489 21.0 <class 'float'>
# 490 37.0 <class 'float'>
# 491 44.0 <class 'float'>
# 492 35.0 <class 'float'>
# 493 32.0 <class 'float'>
# 494 21.0 <class 'float'>
# 495 40.0 <class 'float'>
# 496 28.0 <class 'float'>
# 497 25.0 <class 'float'>
# 498 34.0 <class 'float'>
# 499 nan <class 'float'>
# 500 38.0 <class 'float'>
# 501 31.0 <class 'float'>
# 502 29.0 <class 'float'>
# 503 29.0 <class 'float'>
# 504 27.0 <class 'float'>
# 505 40.0 <class 'float'>
# 506 35.0 <class 'float'>
# 507 39.0 <class 'float'>
# 508 37.0 <class 'float'>
# 509 28.0 <class 'float'>
# 510 27.0 <class 'float'>
# 511 22.0 <class 'float'>
# 512 24.0 <class 'float'>
# 513 38.0 <class 'float'>
# 514 28.0 <class 'float'>
# 515 28.0 <class 'float'>
# 516 19.0 <class 'float'>
# 517 26.0 <class 'float'>
# 518 33.0 <class 'float'>
# 519 nan <class 'float'>
# 520 20.0 <class 'float'>
# 521 30.0 <class 'float'>
# 522 nan <class 'float'>
# 523 38.0 <class 'float'>
# 524 42.0 <class 'float'>
# 525 25.0 <class 'float'>
# 526 26.0 <class 'float'>
# 527 22.0 <class 'float'>
# 528 27.0 <class 'float'>
# 529 37.0 <class 'float'>
# 530 nan <class 'float'>
# 531 28.0 <class 'float'>
# 532 27.0 <class 'float'>
# 533 30.0 <class 'float'>
# 534 24.0 <class 'float'>
# 535 29.0 <class 'float'>
# 536 24.0 <class 'float'>
# 537 28.0 <class 'float'>
# 538 36.0 <class 'float'>
# 539 25.0 <class 'float'>
# 540 23.0 <class 'float'>
# 541 30.0 <class 'float'>
# 542 29.0 <class 'float'>
# 543 42.0 <class 'float'>
# 544 44.0 <class 'float'>
# 545 33.0 <class 'float'>
# 546 27.0 <class 'float'>
# 547 28.0 <class 'float'>
# 548 37.0 <class 'float'>
# 549 33.0 <class 'float'>
# 550 27.0 <class 'float'>
# 551 40.0 <class 'float'>
# 552 28.0 <class 'float'>
# 553 26.0 <class 'float'>
# 554 49.0 <class 'float'>
# 555 36.0 <class 'float'>
# 556 23.0 <class 'float'>
# 557 34.0 <class 'float'>
# 558 27.0 <class 'float'>
# 559 31.0 <class 'float'>
# 560 29.0 <class 'float'>
# 561 26.0 <class 'float'>
# 562 20.0 <class 'float'>
# 563 57.0 <class 'float'>
# 564 38.0 <class 'float'>
# 565 27.0 <class 'float'>
# 566 28.0 <class 'float'>
# 567 32.0 <class 'float'>
# 568 28.0 <class 'float'>
# 569 29.0 <class 'float'>
# 570 26.0 <class 'float'>
# 571 31.0 <class 'float'>
# 572 34.0 <class 'float'>
# 573 22.0 <class 'float'>
# 574 25.0 <class 'float'>
# 575 38.0 <class 'float'>
# 576 27.0 <class 'float'>
# 577 37.0 <class 'float'>
# 578 32.0 <class 'float'>
# 579 27.0 <class 'float'>
# 580 34.0 <class 'float'>
# 581 39.0 <class 'float'>
# 582 25.0 <class 'float'>
# 583 42.0 <class 'float'>
# 584 23.0 <class 'float'>
# 585 38.0 <class 'float'>
# 586 22.0 <class 'float'>
# 587 34.0 <class 'float'>
# 588 37.0 <class 'float'>
# 589 37.0 <class 'float'>
# 590 29.0 <class 'float'>
# 591 52.0 <class 'float'>
# 592 26.0 <class 'float'>
# 593 28.0 <class 'float'>
# 594 46.0 <class 'float'>
# 595 23.0 <class 'float'>
# 596 28.0 <class 'float'>
# 597 29.0 <class 'float'>
# 598 nan <class 'float'>
# 599 59.0 <class 'float'>
# 600 25.0 <class 'float'>
# 601 36.0 <class 'float'>
# 602 23.0 <class 'float'>
# 603 35.0 <class 'float'>
# 604 35.0 <class 'float'>
# 605 23.0 <class 'float'>
# 606 23.0 <class 'float'>
# 607 24.0 <class 'float'>
# 608 28.0 <class 'float'>
# 609 33.0 <class 'float'>
# 610 29.0 <class 'float'>
# 611 30.0 <class 'float'>
# 612 39.0 <class 'float'>
# 613 35.0 <class 'float'>
# 614 61.0 <class 'float'>
# 615 39.0 <class 'float'>
# 616 28.0 <class 'float'>
# 617 nan <class 'float'>
# 618 36.0 <class 'float'>
# 619 28.0 <class 'float'>
# 620 36.0 <class 'float'>
# 621 30.0 <class 'float'>
# 622 43.0 <class 'float'>
# 623 42.0 <class 'float'>
# 624 36.0 <class 'float'>
# 625 33.0 <class 'float'>
# 626 26.0 <class 'float'>
# 627 33.0 <class 'float'>
# 628 22.0 <class 'float'>
# 629 30.0 <class 'float'>
# 630 42.0 <class 'float'>
# 631 32.0 <class 'float'>
# 632 33.0 <class 'float'>
# 633 23.0 <class 'float'>
# 634 28.0 <class 'float'>
# 635 26.0 <class 'float'>
# 636 32.0 <class 'float'>
# 637 22.0 <class 'float'>
# 638 23.0 <class 'float'>
# 639 22.0 <class 'float'>
# 640 25.0 <class 'float'>
# 641 26.0 <class 'float'>
# 642 29.0 <class 'float'>
# 643 24.0 <class 'float'>
# 644 33.0 <class 'float'>
# 645 35.0 <class 'float'>
# 646 30.0 <class 'float'>
# 647 27.0 <class 'float'>
# 648 22.0 <class 'float'>
# 649 42.0 <class 'float'>
# 650 26.0 <class 'float'>
# 651 38.0 <class 'float'>
# 652 36.0 <class 'float'>
# 653 40.0 <class 'float'>
# 654 26.0 <class 'float'>
# 655 33.0 <class 'float'>
# 656 32.0 <class 'float'>
# 657 29.0 <class 'float'>
# 658 38.0 <class 'float'>
# 659 27.0 <class 'float'>
# 660 27.0 <class 'float'>
# 661 30.0 <class 'float'>
# 662 38.0 <class 'float'>
# 663 46.0 <class 'float'>
# 664 31.0 <class 'float'>
# 665 28.0 <class 'float'>
# 666 35.0 <class 'float'>
# 667 nan <class 'float'>
# 668 19.0 <class 'float'>
# 669 28.0 <class 'float'>
# 670 32.0 <class 'float'>
# 671 31.0 <class 'float'>
# 672 23.0 <class 'float'>
# 673 31.0 <class 'float'>
# 674 22.0 <class 'float'>
# 675 29.0 <class 'float'>
# 676 26.0 <class 'float'>
# 677 22.0 <class 'float'>
# 678 33.0 <class 'float'>
# 679 23.0 <class 'float'>
# 680 38.0 <class 'float'>
# 681 30.0 <class 'float'>
# 682 28.0 <class 'float'>
# 683 40.0 <class 'float'>
# 684 32.0 <class 'float'>
# 685 25.0 <class 'float'>
# 686 26.0 <class 'float'>
# 687 24.0 <class 'float'>
# 688 24.0 <class 'float'>
# 689 34.0 <class 'float'>
# 690 30.0 <class 'float'>
# 691 34.0 <class 'float'>
# 692 40.0 <class 'float'>
# 693 33.0 <class 'float'>
# 694 36.0 <class 'float'>
# 695 34.0 <class 'float'>
# 696 25.0 <class 'float'>
# 697 29.0 <class 'float'>
# 698 35.0 <class 'float'>
# 699 29.0 <class 'float'>
# 700 33.0 <class 'float'>
# 701 20.0 <class 'float'>
# 702 28.0 <class 'float'>
# 703 nan <class 'float'>
# 704 nan <class 'float'>
# 705 22.0 <class 'float'>
# 706 24.0 <class 'float'>
# 707 27.0 <class 'float'>
# 708 34.0 <class 'float'>
# 709 22.0 <class 'float'>
# 710 25.0 <class 'float'>
# 711 34.0 <class 'float'>
# 712 32.0 <class 'float'>
# 713 24.0 <class 'float'>
# 714 25.0 <class 'float'>
# 715 30.0 <class 'float'>
# 716 31.0 <class 'float'>
# 717 28.0 <class 'float'>
# 718 24.0 <class 'float'>
# 719 38.0 <class 'float'>
# 720 41.0 <class 'float'>
# 721 24.0 <class 'float'>
# 722 28.0 <class 'float'>
# 723 33.0 <class 'float'>
# 724 28.0 <class 'float'>
# 725 22.0 <class 'float'>
# 726 23.0 <class 'float'>
# 727 29.0 <class 'float'>
# 728 33.0 <class 'float'>
# 729 45.0 <class 'float'>
# 730 32.0 <class 'float'>
# 731 30.0 <class 'float'>
# 732 49.0 <class 'float'>
# 733 30.0 <class 'float'>
# 734 30.0 <class 'float'>
# 735 27.0 <class 'float'>
# 736 24.0 <class 'float'>
# 737 26.0 <class 'float'>
# 738 22.0 <class 'float'>
# 739 32.0 <class 'float'>
# 740 25.0 <class 'float'>
# 741 26.0 <class 'float'>
# 742 27.0 <class 'float'>
# 743 22.0 <class 'float'>
# 744 57.0 <class 'float'>
# 745 30.0 <class 'float'>
# 746 30.0 <class 'float'>
# 747 63.0 <class 'float'>
# 748 34.0 <class 'float'>
# 749 28.0 <class 'float'>
# 750 27.0 <class 'float'>
# 751 40.0 <class 'float'>
# 752 44.0 <class 'float'>
# 753 26.0 <class 'float'>
# 754 30.0 <class 'float'>
# 755 nan <class 'float'>
# 756 65.0 <class 'float'>
# 757 54.0 <class 'float'>
# 758 33.0 <class 'float'>
# 759 29.0 <class 'float'>
# 760 23.0 <class 'float'>
# 761 23.0 <class 'float'>
# 762 44.0 <class 'float'>
# 763 35.0 <class 'float'>
# 764 34.0 <class 'float'>
# 765 22.0 <class 'float'>
# 766 26.0 <class 'float'>
# 767 31.0 <class 'float'>
# 768 28.0 <class 'float'>
# 769 24.0 <class 'float'>
# 770 35.0 <class 'float'>
# 771 21.0 <class 'float'>
# 772 28.0 <class 'float'>
# 773 32.0 <class 'float'>
# 774 26.0 <class 'float'>
# 775 28.0 <class 'float'>
# 776 24.0 <class 'float'>
# 777 35.0 <class 'float'>
# 778 25.0 <class 'float'>
# 779 29.0 <class 'float'>
# 780 28.0 <class 'float'>
# 781 34.0 <class 'float'>
# 782 34.0 <class 'float'>
# 783 24.0 <class 'float'>
# 784 25.0 <class 'float'>
# 785 23.0 <class 'float'>
# 786 22.0 <class 'float'>
# 787 35.0 <class 'float'>
# 788 42.0 <class 'float'>
# 789 30.0 <class 'float'>
# 790 29.0 <class 'float'>
# 791 49.0 <class 'float'>
# 792 21.0 <class 'float'>
# 793 34.0 <class 'float'>
# 794 24.0 <class 'float'>
# 795 32.0 <class 'float'>
# 796 28.0 <class 'float'>
# 797 44.0 <class 'float'>
# 798 20.0 <class 'float'>
# 799 25.0 <class 'float'>
# 800 30.0 <class 'float'>
# 801 37.0 <class 'float'>
# 802 23.0 <class 'float'>
# 803 31.0 <class 'float'>
# 804 36.0 <class 'float'>
# 805 24.0 <class 'float'>
# 806 35.0 <class 'float'>
# 807 32.0 <class 'float'>
# 808 25.0 <class 'float'>
# 809 29.0 <class 'float'>
# 810 50.0 <class 'float'>
# 811 41.0 <class 'float'>
# 812 34.0 <class 'float'>
# 813 21.0 <class 'float'>
# 814 32.0 <class 'float'>
# 815 26.0 <class 'float'>
# 816 30.0 <class 'float'>
# 817 26.0 <class 'float'>
# 818 23.0 <class 'float'>
# 819 26.0 <class 'float'>
# 820 23.0 <class 'float'>
# 821 36.0 <class 'float'>
# 822 25.0 <class 'float'>
# 823 27.0 <class 'float'>
# 824 25.0 <class 'float'>
# 825 28.0 <class 'float'>
# 826 25.0 <class 'float'>
# 827 33.0 <class 'float'>
# 828 29.0 <class 'float'>
# 829 23.0 <class 'float'>
# 830 25.0 <class 'float'>
# 831 29.0 <class 'float'>
# 832 22.0 <class 'float'>
# 833 28.0 <class 'float'>
# 834 30.0 <class 'float'>
# 835 34.0 <class 'float'>
# 836 29.0 <class 'float'>
# 837 24.0 <class 'float'>
# 838 33.0 <class 'float'>
# 839 30.0 <class 'float'>
# 840 29.0 <class 'float'>
# 841 25.0 <class 'float'>
# 842 38.0 <class 'float'>
# 843 24.0 <class 'float'>
# 844 27.0 <class 'float'>
# 845 nan <class 'float'>
# 846 34.0 <class 'float'>
# 847 38.0 <class 'float'>
# 848 22.0 <class 'float'>
# 849 27.0 <class 'float'>
# 850 36.0 <class 'float'>
# 851 27.0 <class 'float'>
# 852 33.0 <class 'float'>
# 853 24.0 <class 'float'>
# 854 28.0 <class 'float'>
# 855 27.0 <class 'float'>
# 856 23.0 <class 'float'>
# 857 29.0 <class 'float'>
# 858 38.0 <class 'float'>
# 859 31.0 <class 'float'>
# 860 25.0 <class 'float'>
# 861 32.0 <class 'float'>
# 862 37.0 <class 'float'>
# 863 44.0 <class 'float'>
# 864 26.0 <class 'float'>
# 865 25.0 <class 'float'>
# 866 28.0 <class 'float'>
# 867 34.0 <class 'float'>
# 868 40.0 <class 'float'>
# 869 38.0 <class 'float'>
# 870 35.0 <class 'float'>
# 871 27.0 <class 'float'>
# 872 50.0 <class 'float'>
# 873 36.0 <class 'float'>
# 874 39.0 <class 'float'>
# 875 30.0 <class 'float'>
# 876 28.0 <class 'float'>
# 877 32.0 <class 'float'>
# 878 nan <class 'float'>
# 879 33.0 <class 'float'>
# 880 43.0 <class 'float'>
# 881 34.0 <class 'float'>
# 882 35.0 <class 'float'>
# 883 25.0 <class 'float'>
# 884 27.0 <class 'float'>
# 885 35.0 <class 'float'>
# 886 31.0 <class 'float'>
# 887 nan <class 'float'>
# 888 27.0 <class 'float'>
# 889 23.0 <class 'float'>
# 890 29.0 <class 'float'>
# 891 21.0 <class 'float'>
# 892 35.0 <class 'float'>
# 893 36.0 <class 'float'>
# 894 27.0 <class 'float'>
# 895 33.0 <class 'float'>
# 896 21.0 <class 'float'>
# 897 32.0 <class 'float'>
# 898 39.0 <class 'float'>
# 899 30.0 <class 'float'>
# 900 28.0 <class 'float'>
# 901 41.0 <class 'float'>
# 902 35.0 <class 'float'>
# 903 29.0 <class 'float'>
# 904 35.0 <class 'float'>
# 905 29.0 <class 'float'>
# 906 35.0 <class 'float'>
# 907 49.0 <class 'float'>
# 908 32.0 <class 'float'>
# 909 36.0 <class 'float'>
# 910 46.0 <class 'float'>
# 911 26.0 <class 'float'>
# 912 29.0 <class 'float'>
# 913 41.0 <class 'float'>
# 914 37.0 <class 'float'>
# 915 40.0 <class 'float'>
# 916 27.0 <class 'float'>
# 917 33.0 <class 'float'>
# 918 34.0 <class 'float'>
# 919 37.0 <class 'float'>
# 920 24.0 <class 'float'>
# 921 25.0 <class 'float'>
# 922 50.0 <class 'float'>
# 923 35.0 <class 'float'>
# 924 29.0 <class 'float'>
# 925 28.0 <class 'float'>
# 926 24.0 <class 'float'>
# 927 24.0 <class 'float'>
# 928 23.0 <class 'float'>
# 929 36.0 <class 'float'>
# 930 24.0 <class 'float'>
# 931 22.0 <class 'float'>
# 932 27.0 <class 'float'>
# 933 31.0 <class 'float'>
# 934 45.0 <class 'float'>
# 935 25.0 <class 'float'>
# 936 35.0 <class 'float'>
# 937 50.0 <class 'float'>
# 938 37.0 <class 'float'>
# 939 40.0 <class 'float'>
# 940 25.0 <class 'float'>
# 941 36.0 <class 'float'>
# 942 43.0 <class 'float'>
# 943 21.0 <class 'float'>
# 944 43.0 <class 'float'>
# 945 25.0 <class 'float'>
# 946 32.0 <class 'float'>
# 947 20.0 <class 'float'>
# 948 nan <class 'float'>
# 949 23.0 <class 'float'>
# 950 40.0 <class 'float'>
# 951 45.0 <class 'float'>
# 952 28.0 <class 'float'>
# 953 28.0 <class 'float'>
# 954 46.0 <class 'float'>
# 955 27.0 <class 'float'>
# 956 36.0 <class 'float'>
# 957 31.0 <class 'float'>
# 958 32.0 <class 'float'>
# 959 29.0 <class 'float'>
# 960 25.0 <class 'float'>
# 961 26.0 <class 'float'>
# 962 28.0 <class 'float'>
# 963 18.0 <class 'float'>
# 964 27.0 <class 'float'>
# 965 33.0 <class 'float'>
# 966 23.0 <class 'float'>
# 967 22.0 <class 'float'>
# 968 22.0 <class 'float'>
# 969 23.0 <class 'float'>
# 970 26.0 <class 'float'>
# 971 31.0 <class 'float'>
# 972 24.0 <class 'float'>
# 973 20.0 <class 'float'>
# 974 29.0 <class 'float'>
# 975 30.0 <class 'float'>
# 976 39.0 <class 'float'>
# 977 30.0 <class 'float'>
# 978 24.0 <class 'float'>
# 979 41.0 <class 'float'>
# 980 nan <class 'float'>
# 981 50.0 <class 'float'>
# 982 28.0 <class 'float'>
# 983 41.0 <class 'float'>
# 984 39.0 <class 'float'>
# 985 27.0 <class 'float'>
# 986 25.0 <class 'float'>
# 987 32.0 <class 'float'>
# 988 32.0 <class 'float'>
# 989 29.0 <class 'float'>
# 990 35.0 <class 'float'>
# 991 34.0 <class 'float'>
# 992 28.0 <class 'float'>
# 993 28.0 <class 'float'>
# 994 27.0 <class 'float'>
# 995 50.0 <class 'float'>
# 996 28.0 <class 'float'>
# 997 30.0 <class 'float'>
# 998 35.0 <class 'float'>
# 999 22.0 <class 'float'>
# 1000 30.0 <class 'float'>
# 1001 26.0 <class 'float'>
# 1002 29.0 <class 'float'>
# 1003 29.0 <class 'float'>
# 1004 26.0 <class 'float'>
# 1005 32.0 <class 'float'>
# 1006 32.0 <class 'float'>
# 1007 nan <class 'float'>
# 1008 27.0 <class 'float'>
# 1009 26.0 <class 'float'>
# 1010 36.0 <class 'float'>
# 1011 26.0 <class 'float'>
# 1012 23.0 <class 'float'>
# 1013 28.0 <class 'float'>
# 1014 24.0 <class 'float'>
# 1015 27.0 <class 'float'>
# 1016 24.0 <class 'float'>
# 1017 24.0 <class 'float'>
# 1018 38.0 <class 'float'>
# 1019 43.0 <class 'float'>
# 1020 22.0 <class 'float'>
# 1021 24.0 <class 'float'>
# 1022 33.0 <class 'float'>
# 1023 33.0 <class 'float'>
# 1024 45.0 <class 'float'>
# 1025 34.0 <class 'float'>
# 1026 45.0 <class 'float'>
# 1027 33.0 <class 'float'>
# 1028 40.0 <class 'float'>
# 1029 27.0 <class 'float'>
# 1030 30.0 <class 'float'>
# 1031 39.0 <class 'float'>
# 1032 26.0 <class 'float'>
# 1033 24.0 <class 'float'>
# 1034 53.0 <class 'float'>
# 1035 27.0 <class 'float'>
# 1036 36.0 <class 'float'>
# 1037 25.0 <class 'float'>
# 1038 31.0 <class 'float'>
# 1039 28.0 <class 'float'>
# 1040 22.0 <class 'float'>
# 1041 43.0 <class 'float'>
# 1042 36.0 <class 'float'>
# 1043 30.0 <class 'float'>
# 1044 31.0 <class 'float'>
# 1045 34.0 <class 'float'>
# 1046 44.0 <class 'float'>
# 1047 37.0 <class 'float'>
# 1048 21.0 <class 'float'>
# 1049 nan <class 'float'>
# 1050 39.0 <class 'float'>
# 1051 33.0 <class 'float'>
# 1052 23.0 <class 'float'>
# 1053 33.0 <class 'float'>
# 1054 24.0 <class 'float'>
# 1055 29.0 <class 'float'>
# 1056 31.0 <class 'float'>
# 1057 24.0 <class 'float'>
# 1058 31.0 <class 'float'>
# 1059 39.0 <class 'float'>
# 1060 30.0 <class 'float'>
# 1061 37.0 <class 'float'>
# 1062 53.0 <class 'float'>
# 1063 35.0 <class 'float'>
# 1064 19.0 <class 'float'>
# 1065 36.0 <class 'float'>
# 1066 31.0 <class 'float'>
# 1067 28.0 <class 'float'>
# 1068 22.0 <class 'float'>
# 1069 28.0 <class 'float'>
# 1070 21.0 <class 'float'>
# 1071 27.0 <class 'float'>
# 1072 21.0 <class 'float'>
# 1073 28.0 <class 'float'>
# 1074 20.0 <class 'float'>
# 1075 36.0 <class 'float'>
# 1076 27.0 <class 'float'>
# 1077 22.0 <class 'float'>
# 1078 27.0 <class 'float'>
# 1079 38.0 <class 'float'>
# 1080 22.0 <class 'float'>
# 1081 22.0 <class 'float'>
# 1082 48.0 <class 'float'>
# 1083 31.0 <class 'float'>
# 1084 34.0 <class 'float'>
# 1085 24.0 <class 'float'>
# 1086 26.0 <class 'float'>
# 1087 28.0 <class 'float'>
# 1088 30.0 <class 'float'>
# 1089 29.0 <class 'float'>
# 1090 23.0 <class 'float'>
# 1091 38.0 <class 'float'>
# 1092 26.0 <class 'float'>
# 1093 25.0 <class 'float'>
# 1094 24.0 <class 'float'>
# 1095 38.0 <class 'float'>
# 1096 25.0 <class 'float'>
# 1097 27.0 <class 'float'>
# 1098 37.0 <class 'float'>
# 1099 25.0 <class 'float'>
# 1100 42.0 <class 'float'>
# 1101 33.0 <class 'float'>
# 1102 34.0 <class 'float'>
# 1103 33.0 <class 'float'>
# 1104 24.0 <class 'float'>
# 1105 38.0 <class 'float'>
# 1106 31.0 <class 'float'>
# 1107 24.0 <class 'float'>
# 1108 24.0 <class 'float'>
# 1109 27.0 <class 'float'>
# 1110 24.0 <class 'float'>
# 1111 nan <class 'float'>
# 1112 47.0 <class 'float'>
# 1113 24.0 <class 'float'>
# 1114 26.0 <class 'float'>
# 1115 30.0 <class 'float'>
# 1116 38.0 <class 'float'>
# 1117 24.0 <class 'float'>
# 1118 47.0 <class 'float'>
# 1119 22.0 <class 'float'>
# 1120 26.0 <class 'float'>
# 1121 23.0 <class 'float'>
# 1122 19.0 <class 'float'>
# 1123 22.0 <class 'float'>
# 1124 41.0 <class 'float'>
# 1125 33.0 <class 'float'>
# 1126 25.0 <class 'float'>
# 1127 27.0 <class 'float'>
# 1128 31.0 <class 'float'>
# 1129 33.0 <class 'float'>
# 1130 44.0 <class 'float'>
# 1131 25.0 <class 'float'>
# 1132 22.0 <class 'float'>
# 1133 18.0 <class 'float'>
# 1134 22.0 <class 'float'>
# 1135 34.0 <class 'float'>
# 1136 30.0 <class 'float'>
# 1137 32.0 <class 'float'>
# 1138 44.0 <class 'float'>
# 1139 28.0 <class 'float'>
# 1140 36.0 <class 'float'>
# 1141 27.0 <class 'float'>
# 1142 46.0 <class 'float'>
# 1143 22.0 <class 'float'>
# 1144 26.0 <class 'float'>
# 1145 37.0 <class 'float'>
# 1146 27.0 <class 'float'>
# 1147 26.0 <class 'float'>
# 1148 48.0 <class 'float'>
# 1149 35.0 <class 'float'>
# 1150 43.0 <class 'float'>
# 1151 nan <class 'float'>
# 1152 38.0 <class 'float'>
# 1153 25.0 <class 'float'>
# 1154 30.0 <class 'float'>
# 1155 23.0 <class 'float'>
# 1156 34.0 <class 'float'>
# 1157 38.0 <class 'float'>
# 1158 nan <class 'float'>
# 1159 32.0 <class 'float'>
# 1160 30.0 <class 'float'>
# 1161 25.0 <class 'float'>
# 1162 25.0 <class 'float'>
# 1163 nan <class 'float'>
# 1164 28.0 <class 'float'>
# 1165 nan <class 'float'>
# 1166 28.0 <class 'float'>
# 1167 33.0 <class 'float'>
# 1168 43.0 <class 'float'>
# 1169 29.0 <class 'float'>
# 1170 27.0 <class 'float'>
# 1171 30.0 <class 'float'>
# 1172 21.0 <class 'float'>
# 1173 22.0 <class 'float'>
# 1174 32.0 <class 'float'>
# 1175 25.0 <class 'float'>
# 1176 34.0 <class 'float'>
# 1177 28.0 <class 'float'>
# 1178 25.0 <class 'float'>
# 1179 38.0 <class 'float'>
# 1180 28.0 <class 'float'>
# 1181 41.0 <class 'float'>
# 1182 23.0 <class 'float'>
# 1183 42.0 <class 'float'>
# 1184 28.0 <class 'float'>
# 1185 61.0 <class 'float'>
# 1186 30.0 <class 'float'>
# 1187 23.0 <class 'float'>
# 1188 31.0 <class 'float'>
# 1189 26.0 <class 'float'>
# 1190 28.0 <class 'float'>
# 1191 29.0 <class 'float'>
# 1192 24.0 <class 'float'>
# 1193 38.0 <class 'float'>
# 1194 29.0 <class 'float'>
# 1195 29.0 <class 'float'>
# 1196 36.0 <class 'float'>
# 1197 33.0 <class 'float'>
# 1198 33.0 <class 'float'>
# 1199 25.0 <class 'float'>
# 1200 25.0 <class 'float'>
# 1201 26.0 <class 'float'>
# 1202 29.0 <class 'float'>
# 1203 18.0 <class 'float'>
# 1204 22.0 <class 'float'>
# 1205 27.0 <class 'float'>
# 1206 52.0 <class 'float'>
# 1207 23.0 <class 'float'>
# 1208 30.0 <class 'float'>
# 1209 39.0 <class 'float'>
# 1210 28.0 <class 'float'>
# 1211 38.0 <class 'float'>
# 1212 21.0 <class 'float'>
# 1213 32.0 <class 'float'>
# 1214 33.0 <class 'float'>
# 1215 29.0 <class 'float'>
# 1216 26.0 <class 'float'>
# 1217 36.0 <class 'float'>
# 1218 27.0 <class 'float'>
# 1219 35.0 <class 'float'>
# 1220 24.0 <class 'float'>
# 1221 27.0 <class 'float'>
# 1222 43.0 <class 'float'>
# 1223 21.0 <class 'float'>
# 1224 26.0 <class 'float'>
# 1225 58.0 <class 'float'>
# 1226 nan <class 'float'>
# 1227 24.0 <class 'float'>
# 1228 29.0 <class 'float'>
# 1229 32.0 <class 'float'>
# 1230 30.0 <class 'float'>
# 1231 36.0 <class 'float'>
# 1232 29.0 <class 'float'>
# 1233 25.0 <class 'float'>
# 1234 31.0 <class 'float'>
# 1235 35.0 <class 'float'>
# 1236 35.0 <class 'float'>
# 1237 29.0 <class 'float'>
# 1238 29.0 <class 'float'>
# 1239 36.0 <class 'float'>
# 1240 27.0 <class 'float'>
# 1241 24.0 <class 'float'>
# 1242 24.0 <class 'float'>
# 1243 28.0 <class 'float'>
# 1244 23.0 <class 'float'>
# 1245 27.0 <class 'float'>
# 1246 24.0 <class 'float'>
# 1247 39.0 <class 'float'>
# 1248 31.0 <class 'float'>
# 1249 34.0 <class 'float'>
# 1250 27.0 <class 'float'>
# 1251 32.0 <class 'float'>
# 1252 35.0 <class 'float'>
# 1253 28.0 <class 'float'>
# 1254 28.0 <class 'float'>
# 1255 30.0 <class 'float'>
# 1256 nan <class 'float'>
# 1257 21.0 <class 'float'>
# 1258 27.0 <class 'float'>
# 1259 34.0 <class 'float'>
# 1260 29.0 <class 'float'>
# 1261 30.0 <class 'float'>
# 1262 25.0 <class 'float'>
# 1263 23.0 <class 'float'>
# 1264 56.0 <class 'float'>
# 1265 22.0 <class 'float'>
# 1266 28.0 <class 'float'>
# 1267 29.0 <class 'float'>
# 1268 42.0 <class 'float'>
# 1269 nan <class 'float'>
# 1270 27.0 <class 'float'>
# 1271 23.0 <class 'float'>
# 1272 nan <class 'float'>
# 1273 22.0 <class 'float'>
# 1274 19.0 <class 'float'>
# 1275 47.0 <class 'float'>
# 1276 20.0 <class 'float'>
# 1277 32.0 <class 'float'>
# 1278 43.0 <class 'float'>
# 1279 32.0 <class 'float'>
# 1280 28.0 <class 'float'>
# 1281 17.0 <class 'float'>
# 1282 25.0 <class 'float'>
# 1283 41.0 <class 'float'>
# 1284 32.0 <class 'float'>
# 1285 32.0 <class 'float'>
# 1286 38.0 <class 'float'>
# 1287 42.0 <class 'float'>
# 1288 25.0 <class 'float'>
# 1289 35.0 <class 'float'>
# 1290 25.0 <class 'float'>
# 1291 36.0 <class 'float'>
# 1292 37.0 <class 'float'>
# 1293 35.0 <class 'float'>
# 1294 31.0 <class 'float'>
# 1295 34.0 <class 'float'>
# 1296 32.0 <class 'float'>
# 1297 25.0 <class 'float'>
# 1298 30.0 <class 'float'>
# 1299 26.0 <class 'float'>
# 1300 42.0 <class 'float'>
# 1301 28.0 <class 'float'>
# 1302 21.0 <class 'float'>
# 1303 41.0 <class 'float'>
# 1304 40.0 <class 'float'>
# 1305 30.0 <class 'float'>
# 1306 34.0 <class 'float'>
# 1307 28.0 <class 'float'>
# 1308 22.0 <class 'float'>
# 1309 28.0 <class 'float'>
# 1310 20.0 <class 'float'>
# 1311 30.0 <class 'float'>
# 1312 22.0 <class 'float'>
# 1313 28.0 <class 'float'>
# 1314 24.0 <class 'float'>
# 1315 40.0 <class 'float'>
# 1316 35.0 <class 'float'>
# 1317 30.0 <class 'float'>
# 1318 30.0 <class 'float'>
# 1319 31.0 <class 'float'>
# 1320 31.0 <class 'float'>
# 1321 27.0 <class 'float'>
# 1322 28.0 <class 'float'>
# 1323 25.0 <class 'float'>
# 1324 23.0 <class 'float'>
# 1325 23.0 <class 'float'>
# 1326 40.0 <class 'float'>
# 1327 38.0 <class 'float'>
# 1328 24.0 <class 'float'>
# 1329 35.0 <class 'float'>
# 1330 23.0 <class 'float'>
# 1331 nan <class 'float'>
# 1332 23.0 <class 'float'>
# 1333 29.0 <class 'float'>
# 1334 nan <class 'float'>
# 1335 29.0 <class 'float'>
# 1336 29.0 <class 'float'>
# 1337 34.0 <class 'float'>
# 1338 32.0 <class 'float'>
# 1339 21.0 <class 'float'>
# 1340 35.0 <class 'float'>
# 1341 24.0 <class 'float'>
# 1342 29.0 <class 'float'>
# 1343 29.0 <class 'float'>
# 1344 28.0 <class 'float'>
# 1345 34.0 <class 'float'>
# 1346 37.0 <class 'float'>
# 1347 25.0 <class 'float'>
# 1348 48.0 <class 'float'>
# 1349 33.0 <class 'float'>
# 1350 45.0 <class 'float'>
# 1351 26.0 <class 'float'>
# 1352 36.0 <class 'float'>
# 1353 30.0 <class 'float'>
# 1354 23.0 <class 'float'>
# 1355 28.0 <class 'float'>
# 1356 30.0 <class 'float'>
# 1357 28.0 <class 'float'>
# 1358 30.0 <class 'float'>
# 1359 41.0 <class 'float'>
# 1360 40.0 <class 'float'>
# 1361 21.0 <class 'float'>
# 1362 38.0 <class 'float'>
# 1363 30.0 <class 'float'>
# 1364 25.0 <class 'float'>
# 1365 38.0 <class 'float'>
# 1366 30.0 <class 'float'>
# 1367 28.0 <class 'float'>
# 1368 26.0 <class 'float'>
# 1369 29.0 <class 'float'>
# 1370 26.0 <class 'float'>
# 1371 34.0 <class 'float'>
# 1372 28.0 <class 'float'>
# 1373 26.0 <class 'float'>
# 1374 23.0 <class 'float'>
# 1375 29.0 <class 'float'>
# 1376 23.0 <class 'float'>
# 1377 40.0 <class 'float'>
# 1378 27.0 <class 'float'>
# 1379 25.0 <class 'float'>
# 1380 50.0 <class 'float'>
# 1381 31.0 <class 'float'>
# 1382 35.0 <class 'float'>
# 1383 29.0 <class 'float'>
# 1384 34.0 <class 'float'>
# 1385 31.0 <class 'float'>
# 1386 nan <class 'float'>
# 1387 27.0 <class 'float'>
# 1388 27.0 <class 'float'>
# 1389 26.0 <class 'float'>
# 1390 29.0 <class 'float'>
# 1391 23.0 <class 'float'>
# 1392 41.0 <class 'float'>
# 1393 23.0 <class 'float'>
# 1394 52.0 <class 'float'>
# 1395 25.0 <class 'float'>
# 1396 22.0 <class 'float'>
# 1397 37.0 <class 'float'>
# 1398 27.0 <class 'float'>
# 1399 21.0 <class 'float'>
# 1400 37.0 <class 'float'>
# 1401 42.0 <class 'float'>
# 1402 22.0 <class 'float'>
# 1403 30.0 <class 'float'>
# 1404 27.0 <class 'float'>
# 1405 34.0 <class 'float'>
# 1406 24.0 <class 'float'>
# 1407 21.0 <class 'float'>
# 1408 30.0 <class 'float'>
# 1409 30.0 <class 'float'>
# 1410 23.0 <class 'float'>
# 1411 33.0 <class 'float'>
# 1412 21.0 <class 'float'>
# 1413 28.0 <class 'float'>
# 1414 27.0 <class 'float'>
# 1415 26.0 <class 'float'>
# 1416 24.0 <class 'float'>
# 1417 43.0 <class 'float'>
# 1418 21.0 <class 'float'>
# 1419 22.0 <class 'float'>
# 1420 26.0 <class 'float'>
# 1421 29.0 <class 'float'>
# 1422 36.0 <class 'float'>
# 1423 46.0 <class 'float'>
# 1424 28.0 <class 'float'>
# 1425 51.0 <class 'float'>
# 1426 24.0 <class 'float'>
# 1427 29.0 <class 'float'>
# 1428 nan <class 'float'>
# 1429 28.0 <class 'float'>
# 1430 44.0 <class 'float'>
# 1431 23.0 <class 'float'>
# 1432 19.0 <class 'float'>
# 1433 42.0 <class 'float'>
# 1434 36.0 <class 'float'>
# 1435 19.0 <class 'float'>
# 1436 43.0 <class 'float'>
# 1437 34.0 <class 'float'>
# 1438 38.0 <class 'float'>
# 1439 53.0 <class 'float'>
# 1440 22.0 <class 'float'>
# 1441 23.0 <class 'float'>
# 1442 31.0 <class 'float'>
# 1443 22.0 <class 'float'>
# 1444 27.0 <class 'float'>
# 1445 37.0 <class 'float'>
# 1446 38.0 <class 'float'>
# 1447 30.0 <class 'float'>
# 1448 34.0 <class 'float'>
# 1449 35.0 <class 'float'>
# 1450 22.0 <class 'float'>
# 1451 24.0 <class 'float'>
# 1452 40.0 <class 'float'>
# 1453 44.0 <class 'float'>
# 1454 26.0 <class 'float'>
# 1455 32.0 <class 'float'>
# 1456 35.0 <class 'float'>
# 1457 34.0 <class 'float'>
# 1458 58.0 <class 'float'>
# 1459 38.0 <class 'float'>
# 1460 29.0 <class 'float'>
# 1461 39.0 <class 'float'>
# 1462 nan <class 'float'>
# 1463 23.0 <class 'float'>
# 1464 40.0 <class 'float'>
# 1465 24.0 <class 'float'>
# 1466 26.0 <class 'float'>
# 1467 28.0 <class 'float'>
# 1468 28.0 <class 'float'>
# 1469 29.0 <class 'float'>
# 1470 nan <class 'float'>
# 1471 27.0 <class 'float'>
# 1472 33.0 <class 'float'>
# 1473 30.0 <class 'float'>
# 1474 37.0 <class 'float'>
# 1475 26.0 <class 'float'>
# 1476 30.0 <class 'float'>
# 1477 19.0 <class 'float'>
# 1478 29.0 <class 'float'>
# 1479 31.0 <class 'float'>
# 1480 40.0 <class 'float'>
# 1481 28.0 <class 'float'>
# 1482 25.0 <class 'float'>
# 1483 31.0 <class 'float'>
# 1484 37.0 <class 'float'>
# 1485 32.0 <class 'float'>
# 1486 41.0 <class 'float'>
# 1487 25.0 <class 'float'>
# 1488 25.0 <class 'float'>
# 1489 37.0 <class 'float'>
# 1490 50.0 <class 'float'>
# 1491 38.0 <class 'float'>
# 1492 24.0 <class 'float'>
# 1493 27.0 <class 'float'>
# 1494 nan <class 'float'>
# 1495 27.0 <class 'float'>
# 1496 56.0 <class 'float'>
# 1497 36.0 <class 'float'>
# 1498 25.0 <class 'float'>
# 1499 34.0 <class 'float'>
# 1500 25.0 <class 'float'>
# 1501 42.0 <class 'float'>
# 1502 43.0 <class 'float'>
# 1503 33.0 <class 'float'>
# 1504 27.0 <class 'float'>
# 1505 31.0 <class 'float'>
# 1506 33.0 <class 'float'>
# 1507 30.0 <class 'float'>
# 1508 28.0 <class 'float'>
# 1509 23.0 <class 'float'>
# 1510 41.0 <class 'float'>
# 1511 32.0 <class 'float'>
# 1512 32.0 <class 'float'>
# 1513 35.0 <class 'float'>
# 1514 24.0 <class 'float'>
# 1515 24.0 <class 'float'>
# 1516 45.0 <class 'float'>
# 1517 26.0 <class 'float'>
# 1518 34.0 <class 'float'>
# 1519 24.0 <class 'float'>
# 1520 22.0 <class 'float'>
# 1521 39.0 <class 'float'>
# 1522 32.0 <class 'float'>
# 1523 37.0 <class 'float'>
# 1524 33.0 <class 'float'>
# 1525 41.0 <class 'float'>
# 1526 33.0 <class 'float'>
# 1527 32.0 <class 'float'>
# 1528 33.0 <class 'float'>
# 1529 34.0 <class 'float'>
# 1530 57.0 <class 'float'>
# 1531 35.0 <class 'float'>
# 1532 21.0 <class 'float'>
# 1533 32.0 <class 'float'>
# 1534 24.0 <class 'float'>
# 1535 45.0 <class 'float'>
# 1536 38.0 <class 'float'>
# 1537 22.0 <class 'float'>
# 1538 45.0 <class 'float'>
# 1539 32.0 <class 'float'>
# 1540 44.0 <class 'float'>
# 1541 23.0 <class 'float'>
# 1542 28.0 <class 'float'>
# 1543 29.0 <class 'float'>
# 1544 42.0 <class 'float'>
# 1545 29.0 <class 'float'>
# 1546 33.0 <class 'float'>
# 1547 26.0 <class 'float'>
# 1548 43.0 <class 'float'>
# 1549 26.0 <class 'float'>
# 1550 44.0 <class 'float'>
# 1551 19.0 <class 'float'>
# 1552 21.0 <class 'float'>
# 1553 46.5 <class 'float'>
# 1554 41.0 <class 'float'>
# 1555 27.0 <class 'float'>
# 1556 31.0 <class 'float'>
# 1557 43.0 <class 'float'>
# 1558 25.0 <class 'float'>
# 1559 nan <class 'float'>
# 1560 32.0 <class 'float'>
# 1561 27.0 <class 'float'>
# 1562 33.0 <class 'float'>
# 1563 25.0 <class 'float'>
# 1564 27.0 <class 'float'>
# 1565 22.0 <class 'float'>
# 1566 22.0 <class 'float'>
# 1567 23.0 <class 'float'>
# 1568 24.0 <class 'float'>
# 1569 31.0 <class 'float'>
# 1570 26.0 <class 'float'>
# 1571 36.0 <class 'float'>
# 1572 47.0 <class 'float'>
# 1573 52.0 <class 'float'>
# 1574 nan <class 'float'>
# 1575 22.0 <class 'float'>
# 1576 29.0 <class 'float'>
# 1577 22.0 <class 'float'>
# 1578 32.0 <class 'float'>
# 1579 28.0 <class 'float'>
# 1580 32.0 <class 'float'>
# 1581 24.0 <class 'float'>
# 1582 23.0 <class 'float'>
# 1583 27.0 <class 'float'>
# 1584 31.0 <class 'float'>
# 1585 nan <class 'float'>
# 1586 30.0 <class 'float'>
# 1587 29.0 <class 'float'>
# 1588 27.0 <class 'float'>
# 1589 36.0 <class 'float'>
# 1590 32.0 <class 'float'>
# 1591 31.0 <class 'float'>
# 1592 28.0 <class 'float'>
# 1593 35.0 <class 'float'>
# 1594 23.0 <class 'float'>
# 1595 61.0 <class 'float'>
# 1596 29.0 <class 'float'>
# 1597 29.0 <class 'float'>
# 1598 26.0 <class 'float'>
# 1599 40.0 <class 'float'>
# 1600 42.0 <class 'float'>
# 1601 nan <class 'float'>
# 1602 31.0 <class 'float'>
# 1603 26.0 <class 'float'>
# 1604 25.0 <class 'float'>
# 1605 25.0 <class 'float'>
# 1606 31.0 <class 'float'>
# 1607 53.0 <class 'float'>
# 1608 26.0 <class 'float'>
# 1609 26.0 <class 'float'>
# 1610 28.0 <class 'float'>
# 1611 30.0 <class 'float'>
# 1612 41.0 <class 'float'>
# 1613 46.0 <class 'float'>
# 1614 24.0 <class 'float'>
# 1615 30.0 <class 'float'>
# 1616 31.0 <class 'float'>
# 1617 24.0 <class 'float'>
# 1618 27.0 <class 'float'>
# 1619 37.0 <class 'float'>
# 1620 nan <class 'float'>
# 1621 26.0 <class 'float'>
# 1622 33.0 <class 'float'>
# 1623 30.0 <class 'float'>
# 1624 24.0 <class 'float'>
# 1625 23.0 <class 'float'>
# 1626 23.0 <class 'float'>
# 1627 29.0 <class 'float'>
# 1628 31.0 <class 'float'>
# 1629 27.0 <class 'float'>
# 1630 31.0 <class 'float'>
# 1631 35.0 <class 'float'>
# 1632 26.0 <class 'float'>
# 1633 20.0 <class 'float'>
# 1634 50.0 <class 'float'>
# 1635 24.0 <class 'float'>
# 1636 28.0 <class 'float'>
# 1637 37.0 <class 'float'>
# 1638 nan <class 'float'>
# 1639 43.0 <class 'float'>
# 1640 37.0 <class 'float'>
# 1641 33.0 <class 'float'>
# 1642 27.0 <class 'float'>
# 1643 24.0 <class 'float'>
# 1644 27.0 <class 'float'>
# 1645 35.0 <class 'float'>
# 1646 26.0 <class 'float'>
# 1647 30.0 <class 'float'>
# 1648 24.0 <class 'float'>
# 1649 27.0 <class 'float'>
# 1650 32.0 <class 'float'>
# 1651 32.0 <class 'float'>
# 1652 25.0 <class 'float'>
# 1653 41.0 <class 'float'>
# 1654 37.0 <class 'float'>
# 1655 28.0 <class 'float'>
# 1656 26.0 <class 'float'>
# 1657 27.0 <class 'float'>
# 1658 63.0 <class 'float'>
# 1659 25.0 <class 'float'>
# 1660 31.0 <class 'float'>
# 1661 38.0 <class 'float'>
# 1662 27.0 <class 'float'>
# 1663 23.0 <class 'float'>
# 1664 34.0 <class 'float'>
# 1665 29.0 <class 'float'>
# 1666 39.0 <class 'float'>
# 1667 26.0 <class 'float'>
# 1668 35.0 <class 'float'>
# 1669 36.0 <class 'float'>
# 1670 19.0 <class 'float'>
# 1671 30.0 <class 'float'>
# 1672 23.0 <class 'float'>
# 1673 33.0 <class 'float'>
# 1674 28.0 <class 'float'>
# 1675 24.0 <class 'float'>
# 1676 37.0 <class 'float'>
# 1677 34.0 <class 'float'>
# 1678 40.0 <class 'float'>
# 1679 27.0 <class 'float'>
# 1680 29.0 <class 'float'>
# 1681 34.0 <class 'float'>
# 1682 35.0 <class 'float'>
# 1683 31.0 <class 'float'>
# 1684 24.0 <class 'float'>
# 1685 46.0 <class 'float'>
# 1686 22.0 <class 'float'>
# 1687 35.0 <class 'float'>
# 1688 nan <class 'float'>
# 1689 35.0 <class 'float'>
# 1690 60.0 <class 'float'>
# 1691 34.0 <class 'float'>
# 1692 30.0 <class 'float'>
# 1693 25.0 <class 'float'>
# 1694 24.0 <class 'float'>
# 1695 38.0 <class 'float'>
# 1696 42.0 <class 'float'>
# 1697 31.0 <class 'float'>
# 1698 36.0 <class 'float'>
# 1699 31.0 <class 'float'>
# 1700 34.0 <class 'float'>
# 1701 30.0 <class 'float'>
# 1702 27.0 <class 'float'>
# 1703 38.0 <class 'float'>
# 1704 35.0 <class 'float'>
# 1705 32.0 <class 'float'>
# 1706 26.0 <class 'float'>
# 1707 19.0 <class 'float'>
# 1708 29.0 <class 'float'>
# 1709 33.0 <class 'float'>
# 1710 24.0 <class 'float'>
# 1711 24.0 <class 'float'>
# 1712 28.0 <class 'float'>
# 1713 28.0 <class 'float'>
# 1714 26.0 <class 'float'>
# 1715 32.0 <class 'float'>
# 1716 37.0 <class 'float'>
# 1717 25.0 <class 'float'>
# 1718 38.0 <class 'float'>
# 1719 35.0 <class 'float'>
# 1720 34.0 <class 'float'>
# 1721 32.0 <class 'float'>
# 1722 31.0 <class 'float'>
# 1723 26.0 <class 'float'>
# 1724 nan <class 'float'>
# 1725 31.0 <class 'float'>
# 1726 26.0 <class 'float'>
# 1727 30.0 <class 'float'>
# 1728 34.0 <class 'float'>
# 1729 35.0 <class 'float'>
# 1730 38.0 <class 'float'>
# 1731 37.0 <class 'float'>
# 1732 32.0 <class 'float'>
# 1733 36.0 <class 'float'>
# 1734 43.0 <class 'float'>
# 1735 29.0 <class 'float'>
# 1736 33.0 <class 'float'>
# 1737 25.0 <class 'float'>
# 1738 21.0 <class 'float'>
# 1739 28.0 <class 'float'>
# 1740 25.0 <class 'float'>
# 1741 40.0 <class 'float'>
# 1742 28.0 <class 'float'>
# 1743 29.0 <class 'float'>
# 1744 32.0 <class 'float'>
# 1745 27.0 <class 'float'>
# 1746 31.0 <class 'float'>
# 1747 29.0 <class 'float'>
# 1748 44.0 <class 'float'>
# 1749 26.0 <class 'float'>
# 1750 27.0 <class 'float'>
# 1751 28.0 <class 'float'>
# 1752 29.0 <class 'float'>
# 1753 25.0 <class 'float'>
# 1754 28.0 <class 'float'>
# 1755 23.0 <class 'float'>
# 1756 31.0 <class 'float'>
# 1757 35.0 <class 'float'>
# 1758 42.0 <class 'float'>
# 1759 25.0 <class 'float'>
# 1760 27.0 <class 'float'>
# 1761 22.0 <class 'float'>
# 1762 42.0 <class 'float'>
# 1763 37.0 <class 'float'>
# 1764 28.0 <class 'float'>
# 1765 33.0 <class 'float'>
# 1766 32.0 <class 'float'>
# 1767 26.0 <class 'float'>
# 1768 22.0 <class 'float'>
# 1769 28.0 <class 'float'>
# 1770 30.0 <class 'float'>
# 1771 27.0 <class 'float'>
# 1772 18.0 <class 'float'>
# 1773 32.0 <class 'float'>
# 1774 38.0 <class 'float'>
# 1775 28.0 <class 'float'>
# 1776 24.0 <class 'float'>
# 1777 41.0 <class 'float'>
# 1778 23.0 <class 'float'>
# 1779 31.0 <class 'float'>
# 1780 31.0 <class 'float'>
# 1781 27.0 <class 'float'>
# 1782 22.0 <class 'float'>
# 1783 29.0 <class 'float'>
# 1784 36.0 <class 'float'>
# 1785 27.0 <class 'float'>
# 1786 29.0 <class 'float'>
# 1787 26.0 <class 'float'>
# 1788 22.0 <class 'float'>
# 1789 34.0 <class 'float'>
# 1790 31.0 <class 'float'>
# 1791 24.0 <class 'float'>
# 1792 34.0 <class 'float'>
# 1793 24.0 <class 'float'>
# 1794 30.0 <class 'float'>
# 1795 35.0 <class 'float'>
# 1796 34.0 <class 'float'>
# 1797 35.0 <class 'float'>
# 1798 29.0 <class 'float'>
# 1799 24.0 <class 'float'>
# 1800 29.0 <class 'float'>
# 1801 46.0 <class 'float'>
# 1802 37.0 <class 'float'>
# 1803 34.0 <class 'float'>
# 1804 27.0 <class 'float'>
# 1805 25.0 <class 'float'>
# 1806 45.0 <class 'float'>
# 1807 24.0 <class 'float'>
# 1808 34.0 <class 'float'>
# 1809 39.0 <class 'float'>
# 1810 25.0 <class 'float'>
# 1811 28.0 <class 'float'>
# 1812 48.0 <class 'float'>
# 1813 27.0 <class 'float'>
# 1814 24.0 <class 'float'>
# 1815 30.0 <class 'float'>
# 1816 35.0 <class 'float'>
# 1817 26.0 <class 'float'>
# 1818 23.0 <class 'float'>
# 1819 40.0 <class 'float'>
# 1820 22.0 <class 'float'>
# 1821 25.0 <class 'float'>
# 1822 27.0 <class 'float'>
# 1823 53.0 <class 'float'>
# 1824 37.0 <class 'float'>
# 1825 33.0 <class 'float'>
# 1826 26.0 <class 'float'>
# 1827 24.0 <class 'float'>
# 1828 18.0 <class 'float'>
# 1829 45.0 <class 'float'>
# 1830 42.0 <class 'float'>
# 1831 30.0 <class 'float'>
# 1832 38.0 <class 'float'>
# 1833 28.0 <class 'float'>
# 1834 37.0 <class 'float'>
# 1835 38.0 <class 'float'>
# 1836 28.0 <class 'float'>
# 1837 32.0 <class 'float'>
# 1838 24.0 <class 'float'>
# 1839 27.0 <class 'float'>
# 1840 22.0 <class 'float'>
# 1841 42.0 <class 'float'>
# 1842 38.0 <class 'float'>
# 1843 41.0 <class 'float'>
# 1844 32.0 <class 'float'>
# 1845 37.0 <class 'float'>
# 1846 34.0 <class 'float'>
# 1847 50.0 <class 'float'>
# 1848 33.0 <class 'float'>
# 1849 38.0 <class 'float'>
# 1850 35.0 <class 'float'>
# 1851 44.0 <class 'float'>
# 1852 31.0 <class 'float'>
# 1853 22.0 <class 'float'>
# 1854 29.0 <class 'float'>
# 1855 37.0 <class 'float'>
# 1856 31.0 <class 'float'>
# 1857 29.0 <class 'float'>
# 1858 23.0 <class 'float'>
# 1859 27.0 <class 'float'>
# 1860 46.0 <class 'float'>
# 1861 23.0 <class 'float'>
# 1862 39.0 <class 'float'>
# 1863 21.0 <class 'float'>
# 1864 29.0 <class 'float'>
# 1865 26.0 <class 'float'>
# 1866 36.0 <class 'float'>
# 1867 36.0 <class 'float'>
# 1868 29.0 <class 'float'>
# 1869 19.0 <class 'float'>
# 1870 38.0 <class 'float'>
# 1871 23.0 <class 'float'>
# 1872 44.0 <class 'float'>
# 1873 30.0 <class 'float'>
# 1874 30.0 <class 'float'>
# 1875 38.0 <class 'float'>
# 1876 24.0 <class 'float'>
# 1877 27.0 <class 'float'>
# 1878 29.0 <class 'float'>
# 1879 31.0 <class 'float'>
# 1880 34.0 <class 'float'>
# 1881 33.0 <class 'float'>
# 1882 43.0 <class 'float'>
# 1883 23.0 <class 'float'>
# 1884 25.0 <class 'float'>
# 1885 30.0 <class 'float'>
# 1886 29.0 <class 'float'>
# 1887 23.0 <class 'float'>
# 1888 35.0 <class 'float'>
# 1889 30.0 <class 'float'>
# ...
# 10805 29.0 <class 'float'>
# 10806 27.0 <class 'float'>
# 10807 28.0 <class 'float'>
# 10808 34.0 <class 'float'>
# 10809 41.0 <class 'float'>
# 10810 45.0 <class 'float'>
# 10811 30.0 <class 'float'>
# 10812 28.0 <class 'float'>
# 10813 23.0 <class 'float'>
# 10814 31.0 <class 'float'>
# 10815 40.0 <class 'float'>
# 10816 26.0 <class 'float'>
# 10817 39.0 <class 'float'>
# 10818 29.0 <class 'float'>
# 10819 nan <class 'float'>
# 10820 30.0 <class 'float'>
# 10821 36.0 <class 'float'>
# 10822 36.0 <class 'float'>
# 10823 nan <class 'float'>
# 10824 35.0 <class 'float'>
# 10825 30.0 <class 'float'>
# 10826 28.0 <class 'float'>
# 10827 27.0 <class 'float'>
# 10828 38.0 <class 'float'>
# 10829 36.0 <class 'float'>
# 10830 26.0 <class 'float'>
# 10831 28.0 <class 'float'>
# 10832 29.0 <class 'float'>
# 10833 32.0 <class 'float'>
# 10834 27.0 <class 'float'>
# 10835 43.0 <class 'float'>
# 10836 38.0 <class 'float'>
# 10837 37.0 <class 'float'>
# 10838 32.0 <class 'float'>
# 10839 28.0 <class 'float'>
# 10840 21.0 <class 'float'>
# 10841 26.0 <class 'float'>
# 10842 30.0 <class 'float'>
# 10843 33.0 <class 'float'>
# 10844 24.0 <class 'float'>
# 10845 27.0 <class 'float'>
# 10846 38.0 <class 'float'>
# 10847 25.0 <class 'float'>
# 10848 23.0 <class 'float'>
# 10849 24.0 <class 'float'>
# 10850 nan <class 'float'>
# 10851 25.0 <class 'float'>
# 10852 28.0 <class 'float'>
# 10853 31.0 <class 'float'>
# 10854 32.0 <class 'float'>
# 10855 22.0 <class 'float'>
# 10856 37.0 <class 'float'>
# 10857 29.0 <class 'float'>
# 10858 30.0 <class 'float'>
# 10859 25.0 <class 'float'>
# 10860 29.0 <class 'float'>
# 10861 31.0 <class 'float'>
# 10862 26.0 <class 'float'>
# 10863 30.0 <class 'float'>
# 10864 32.0 <class 'float'>
# 10865 41.0 <class 'float'>
# 10866 38.0 <class 'float'>
# 10867 30.0 <class 'float'>
# 10868 24.0 <class 'float'>
# 10869 31.0 <class 'float'>
# 10870 45.0 <class 'float'>
# 10871 37.0 <class 'float'>
# 10872 27.0 <class 'float'>
# 10873 27.0 <class 'float'>
# 10874 34.0 <class 'float'>
# 10875 33.0 <class 'float'>
# 10876 23.0 <class 'float'>
# 10877 26.0 <class 'float'>
# 10878 23.0 <class 'float'>
# 10879 34.0 <class 'float'>
# 10880 35.0 <class 'float'>
# 10881 28.0 <class 'float'>
# 10882 31.0 <class 'float'>
# 10883 28.0 <class 'float'>
# 10884 24.0 <class 'float'>
# 10885 38.0 <class 'float'>
# 10886 42.0 <class 'float'>
# 10887 33.0 <class 'float'>
# 10888 33.0 <class 'float'>
# 10889 28.0 <class 'float'>
# 10890 33.0 <class 'float'>
# 10891 25.0 <class 'float'>
# 10892 23.0 <class 'float'>
# 10893 32.0 <class 'float'>
# 10894 28.0 <class 'float'>
# 10895 34.0 <class 'float'>
# 10896 24.0 <class 'float'>
# 10897 24.0 <class 'float'>
# 10898 31.0 <class 'float'>
# 10899 26.0 <class 'float'>
# 10900 29.0 <class 'float'>
# 10901 38.0 <class 'float'>
# 10902 33.0 <class 'float'>
# 10903 28.0 <class 'float'>
# 10904 nan <class 'float'>
# 10905 35.0 <class 'float'>
# 10906 29.0 <class 'float'>
# 10907 26.0 <class 'float'>
# 10908 43.0 <class 'float'>
# 10909 25.0 <class 'float'>
# 10910 26.0 <class 'float'>
# 10911 35.0 <class 'float'>
# 10912 23.0 <class 'float'>
# 10913 39.0 <class 'float'>
# 10914 27.0 <class 'float'>
# 10915 38.0 <class 'float'>
# 10916 nan <class 'float'>
# 10917 39.0 <class 'float'>
# 10918 27.0 <class 'float'>
# 10919 31.0 <class 'float'>
# 10920 32.0 <class 'float'>
# 10921 22.0 <class 'float'>
# 10922 25.0 <class 'float'>
# 10923 33.0 <class 'float'>
# 10924 27.0 <class 'float'>
# 10925 28.0 <class 'float'>
# 10926 26.0 <class 'float'>
# 10927 32.0 <class 'float'>
# 10928 40.0 <class 'float'>
# 10929 41.0 <class 'float'>
# 10930 31.0 <class 'float'>
# 10931 33.0 <class 'float'>
# 10932 45.0 <class 'float'>
# 10933 34.0 <class 'float'>
# 10934 37.0 <class 'float'>
# 10935 28.0 <class 'float'>
# 10936 33.0 <class 'float'>
# 10937 27.0 <class 'float'>
# 10938 27.0 <class 'float'>
# 10939 27.0 <class 'float'>
# 10940 23.0 <class 'float'>
# 10941 34.0 <class 'float'>
# 10942 22.0 <class 'float'>
# 10943 nan <class 'float'>
# 10944 30.0 <class 'float'>
# 10945 49.0 <class 'float'>
# 10946 26.0 <class 'float'>
# 10947 31.0 <class 'float'>
# 10948 35.0 <class 'float'>
# 10949 24.0 <class 'float'>
# 10950 51.0 <class 'float'>
# 10951 26.0 <class 'float'>
# 10952 33.0 <class 'float'>
# 10953 29.0 <class 'float'>
# 10954 33.0 <class 'float'>
# 10955 30.0 <class 'float'>
# 10956 29.0 <class 'float'>
# 10957 31.0 <class 'float'>
# 10958 31.0 <class 'float'>
# 10959 27.0 <class 'float'>
# 10960 25.0 <class 'float'>
# 10961 29.0 <class 'float'>
# 10962 23.0 <class 'float'>
# 10963 nan <class 'float'>
# 10964 28.0 <class 'float'>
# 10965 29.0 <class 'float'>
# 10966 35.0 <class 'float'>
# 10967 23.0 <class 'float'>
# 10968 21.0 <class 'float'>
# 10969 20.0 <class 'float'>
# 10970 28.0 <class 'float'>
# 10971 27.0 <class 'float'>
# 10972 31.0 <class 'float'>
# 10973 32.0 <class 'float'>
# 10974 26.0 <class 'float'>
# 10975 27.0 <class 'float'>
# 10976 18.0 <class 'float'>
# 10977 23.0 <class 'float'>
# 10978 24.0 <class 'float'>
# 10979 43.0 <class 'float'>
# 10980 24.0 <class 'float'>
# 10981 29.0 <class 'float'>
# 10982 28.0 <class 'float'>
# 10983 35.0 <class 'float'>
# 10984 42.0 <class 'float'>
# 10985 38.0 <class 'float'>
# 10986 25.0 <class 'float'>
# 10987 41.0 <class 'float'>
# 10988 38.0 <class 'float'>
# 10989 46.0 <class 'float'>
# 10990 40.0 <class 'float'>
# 10991 24.0 <class 'float'>
# 10992 28.0 <class 'float'>
# 10993 28.0 <class 'float'>
# 10994 28.0 <class 'float'>
# 10995 27.0 <class 'float'>
# 10996 42.0 <class 'float'>
# 10997 27.0 <class 'float'>
# 10998 39.0 <class 'float'>
# 10999 35.0 <class 'float'>
# 11000 34.0 <class 'float'>
# 11001 37.0 <class 'float'>
# 11002 26.0 <class 'float'>
# 11003 35.0 <class 'float'>
# 11004 42.0 <class 'float'>
# 11005 32.0 <class 'float'>
# 11006 32.0 <class 'float'>
# 11007 29.0 <class 'float'>
# 11008 26.0 <class 'float'>
# 11009 28.0 <class 'float'>
# 11010 22.0 <class 'float'>
# 11011 40.0 <class 'float'>
# 11012 28.0 <class 'float'>
# 11013 24.0 <class 'float'>
# 11014 22.0 <class 'float'>
# 11015 23.0 <class 'float'>
# 11016 27.0 <class 'float'>
# 11017 22.0 <class 'float'>
# 11018 35.0 <class 'float'>
# 11019 34.0 <class 'float'>
# 11020 38.0 <class 'float'>
# 11021 27.0 <class 'float'>
# 11022 29.0 <class 'float'>
# 11023 26.0 <class 'float'>
# 11024 32.0 <class 'float'>
# 11025 22.0 <class 'float'>
# 11026 48.0 <class 'float'>
# 11027 41.0 <class 'float'>
# 11028 25.0 <class 'float'>
# 11029 35.0 <class 'float'>
# 11030 28.0 <class 'float'>
# 11031 20.0 <class 'float'>
# 11032 30.0 <class 'float'>
# 11033 33.0 <class 'float'>
# 11034 40.0 <class 'float'>
# 11035 31.0 <class 'float'>
# 11036 49.0 <class 'float'>
# 11037 27.0 <class 'float'>
# 11038 28.0 <class 'float'>
# 11039 30.0 <class 'float'>
# 11040 28.0 <class 'float'>
# 11041 27.0 <class 'float'>
# 11042 19.0 <class 'float'>
# 11043 21.0 <class 'float'>
# 11044 35.0 <class 'float'>
# 11045 27.0 <class 'float'>
# 11046 37.0 <class 'float'>
# 11047 35.0 <class 'float'>
# 11048 23.0 <class 'float'>
# 11049 26.0 <class 'float'>
# 11050 34.0 <class 'float'>
# 11051 29.0 <class 'float'>
# 11052 33.0 <class 'float'>
# 11053 32.0 <class 'float'>
# 11054 24.0 <class 'float'>
# 11055 21.0 <class 'float'>
# 11056 23.0 <class 'float'>
# 11057 34.0 <class 'float'>
# 11058 26.0 <class 'float'>
# 11059 21.0 <class 'float'>
# 11060 18.0 <class 'float'>
# 11061 23.0 <class 'float'>
# 11062 21.0 <class 'float'>
# 11063 63.0 <class 'float'>
# 11064 30.0 <class 'float'>
# 11065 24.0 <class 'float'>
# 11066 47.0 <class 'float'>
# 11067 nan <class 'float'>
# 11068 44.0 <class 'float'>
# 11069 24.0 <class 'float'>
# 11070 31.0 <class 'float'>
# 11071 21.0 <class 'float'>
# 11072 33.0 <class 'float'>
# 11073 24.0 <class 'float'>
# 11074 23.0 <class 'float'>
# 11075 24.0 <class 'float'>
# 11076 32.0 <class 'float'>
# 11077 35.0 <class 'float'>
# 11078 34.0 <class 'float'>
# 11079 22.0 <class 'float'>
# 11080 26.0 <class 'float'>
# 11081 28.0 <class 'float'>
# 11082 31.0 <class 'float'>
# 11083 25.0 <class 'float'>
# 11084 23.0 <class 'float'>
# 11085 25.0 <class 'float'>
# 11086 31.0 <class 'float'>
# 11087 24.0 <class 'float'>
# 11088 25.0 <class 'float'>
# 11089 26.0 <class 'float'>
# 11090 27.0 <class 'float'>
# 11091 26.0 <class 'float'>
# 11092 30.0 <class 'float'>
# 11093 22.0 <class 'float'>
# 11094 30.0 <class 'float'>
# 11095 47.0 <class 'float'>
# 11096 26.0 <class 'float'>
# 11097 24.0 <class 'float'>
# 11098 25.0 <class 'float'>
# 11099 22.0 <class 'float'>
# 11100 22.0 <class 'float'>
# 11101 22.0 <class 'float'>
# 11102 31.0 <class 'float'>
# 11103 36.0 <class 'float'>
# 11104 39.0 <class 'float'>
# 11105 25.0 <class 'float'>
# 11106 35.0 <class 'float'>
# 11107 25.0 <class 'float'>
# 11108 48.0 <class 'float'>
# 11109 52.0 <class 'float'>
# 11110 32.0 <class 'float'>
# 11111 40.0 <class 'float'>
# 11112 19.0 <class 'float'>
# 11113 28.0 <class 'float'>
# 11114 49.0 <class 'float'>
# 11115 33.0 <class 'float'>
# 11116 28.0 <class 'float'>
# 11117 27.0 <class 'float'>
# 11118 27.0 <class 'float'>
# 11119 32.0 <class 'float'>
# 11120 35.0 <class 'float'>
# 11121 34.0 <class 'float'>
# 11122 23.0 <class 'float'>
# 11123 27.0 <class 'float'>
# 11124 44.0 <class 'float'>
# 11125 22.0 <class 'float'>
# 11126 24.0 <class 'float'>
# 11127 32.0 <class 'float'>
# 11128 29.0 <class 'float'>
# 11129 34.0 <class 'float'>
# 11130 28.0 <class 'float'>
# 11131 33.0 <class 'float'>
# 11132 28.0 <class 'float'>
# 11133 28.0 <class 'float'>
# 11134 33.0 <class 'float'>
# 11135 27.0 <class 'float'>
# 11136 25.0 <class 'float'>
# 11137 33.0 <class 'float'>
# 11138 41.0 <class 'float'>
# 11139 45.0 <class 'float'>
# 11140 23.0 <class 'float'>
# 11141 28.0 <class 'float'>
# 11142 28.0 <class 'float'>
# 11143 26.0 <class 'float'>
# 11144 28.0 <class 'float'>
# 11145 37.0 <class 'float'>
# 11146 31.0 <class 'float'>
# 11147 23.0 <class 'float'>
# 11148 29.0 <class 'float'>
# 11149 44.0 <class 'float'>
# 11150 31.0 <class 'float'>
# 11151 30.0 <class 'float'>
# 11152 33.0 <class 'float'>
# 11153 29.0 <class 'float'>
# 11154 28.0 <class 'float'>
# 11155 24.0 <class 'float'>
# 11156 23.0 <class 'float'>
# 11157 31.0 <class 'float'>
# 11158 37.0 <class 'float'>
# 11159 43.0 <class 'float'>
# 11160 38.0 <class 'float'>
# 11161 34.0 <class 'float'>
# 11162 49.0 <class 'float'>
# 11163 25.0 <class 'float'>
# 11164 38.0 <class 'float'>
# 11165 24.0 <class 'float'>
# 11166 27.0 <class 'float'>
# 11167 nan <class 'float'>
# 11168 39.0 <class 'float'>
# 11169 24.0 <class 'float'>
# 11170 30.0 <class 'float'>
# 11171 22.0 <class 'float'>
# 11172 37.0 <class 'float'>
# 11173 42.0 <class 'float'>
# 11174 25.0 <class 'float'>
# 11175 26.0 <class 'float'>
# 11176 32.0 <class 'float'>
# 11177 38.0 <class 'float'>
# 11178 24.0 <class 'float'>
# 11179 22.0 <class 'float'>
# 11180 27.0 <class 'float'>
# 11181 35.0 <class 'float'>
# 11182 30.0 <class 'float'>
# 11183 28.0 <class 'float'>
# 11184 33.0 <class 'float'>
# 11185 24.0 <class 'float'>
# 11186 42.0 <class 'float'>
# 11187 26.0 <class 'float'>
# 11188 25.0 <class 'float'>
# 11189 33.0 <class 'float'>
# 11190 26.0 <class 'float'>
# 11191 31.0 <class 'float'>
# 11192 52.0 <class 'float'>
# 11193 33.0 <class 'float'>
# 11194 38.0 <class 'float'>
# 11195 28.0 <class 'float'>
# 11196 41.0 <class 'float'>
# 11197 23.0 <class 'float'>
# 11198 26.0 <class 'float'>
# 11199 34.0 <class 'float'>
# 11200 28.0 <class 'float'>
# 11201 33.0 <class 'float'>
# 11202 27.0 <class 'float'>
# 11203 20.0 <class 'float'>
# 11204 29.0 <class 'float'>
# 11205 33.0 <class 'float'>
# 11206 21.0 <class 'float'>
# 11207 33.0 <class 'float'>
# 11208 24.0 <class 'float'>
# 11209 32.0 <class 'float'>
# 11210 33.0 <class 'float'>
# 11211 36.0 <class 'float'>
# 11212 30.0 <class 'float'>
# 11213 27.0 <class 'float'>
# 11214 23.0 <class 'float'>
# 11215 43.0 <class 'float'>
# 11216 26.0 <class 'float'>
# 11217 29.0 <class 'float'>
# 11218 23.0 <class 'float'>
# 11219 27.0 <class 'float'>
# 11220 41.0 <class 'float'>
# 11221 42.0 <class 'float'>
# 11222 32.0 <class 'float'>
# 11223 42.0 <class 'float'>
# 11224 24.0 <class 'float'>
# 11225 26.0 <class 'float'>
# 11226 30.0 <class 'float'>
# 11227 29.0 <class 'float'>
# 11228 22.0 <class 'float'>
# 11229 35.0 <class 'float'>
# 11230 31.0 <class 'float'>
# 11231 24.0 <class 'float'>
# 11232 29.0 <class 'float'>
# 11233 30.0 <class 'float'>
# 11234 38.0 <class 'float'>
# 11235 25.0 <class 'float'>
# 11236 27.0 <class 'float'>
# 11237 35.0 <class 'float'>
# 11238 30.0 <class 'float'>
# 11239 38.0 <class 'float'>
# 11240 25.0 <class 'float'>
# 11241 27.0 <class 'float'>
# 11242 35.0 <class 'float'>
# 11243 34.0 <class 'float'>
# 11244 31.0 <class 'float'>
# 11245 30.0 <class 'float'>
# 11246 54.0 <class 'float'>
# 11247 29.0 <class 'float'>
# 11248 32.0 <class 'float'>
# 11249 43.0 <class 'float'>
# 11250 22.0 <class 'float'>
# 11251 41.0 <class 'float'>
# 11252 42.0 <class 'float'>
# 11253 40.0 <class 'float'>
# 11254 24.0 <class 'float'>
# 11255 24.0 <class 'float'>
# 11256 25.0 <class 'float'>
# 11257 24.0 <class 'float'>
# 11258 26.0 <class 'float'>
# 11259 32.0 <class 'float'>
# 11260 25.0 <class 'float'>
# 11261 21.0 <class 'float'>
# 11262 33.0 <class 'float'>
# 11263 23.0 <class 'float'>
# 11264 31.0 <class 'float'>
# 11265 23.0 <class 'float'>
# 11266 31.0 <class 'float'>
# 11267 27.0 <class 'float'>
# 11268 27.0 <class 'float'>
# 11269 23.0 <class 'float'>
# 11270 25.0 <class 'float'>
# 11271 24.0 <class 'float'>
# 11272 21.0 <class 'float'>
# 11273 27.0 <class 'float'>
# 11274 41.0 <class 'float'>
# 11275 24.0 <class 'float'>
# 11276 33.0 <class 'float'>
# 11277 22.0 <class 'float'>
# 11278 22.0 <class 'float'>
# 11279 26.0 <class 'float'>
# 11280 36.0 <class 'float'>
# 11281 26.0 <class 'float'>
# 11282 nan <class 'float'>
# 11283 nan <class 'float'>
# 11284 29.0 <class 'float'>
# 11285 35.0 <class 'float'>
# 11286 22.0 <class 'float'>
# 11287 28.0 <class 'float'>
# 11288 52.0 <class 'float'>
# 11289 21.0 <class 'float'>
# 11290 35.0 <class 'float'>
# 11291 38.0 <class 'float'>
# 11292 33.0 <class 'float'>
# 11293 24.0 <class 'float'>
# 11294 30.0 <class 'float'>
# 11295 33.0 <class 'float'>
# 11296 27.0 <class 'float'>
# 11297 24.0 <class 'float'>
# 11298 20.0 <class 'float'>
# 11299 32.0 <class 'float'>
# 11300 23.0 <class 'float'>
# 11301 24.0 <class 'float'>
# 11302 26.0 <class 'float'>
# 11303 45.0 <class 'float'>
# 11304 27.0 <class 'float'>
# 11305 42.0 <class 'float'>
# 11306 25.0 <class 'float'>
# 11307 25.0 <class 'float'>
# 11308 37.0 <class 'float'>
# 11309 36.0 <class 'float'>
# 11310 25.0 <class 'float'>
# 11311 31.0 <class 'float'>
# 11312 25.0 <class 'float'>
# 11313 28.0 <class 'float'>
# 11314 27.0 <class 'float'>
# 11315 20.0 <class 'float'>
# 11316 23.0 <class 'float'>
# 11317 24.0 <class 'float'>
# 11318 36.0 <class 'float'>
# 11319 30.0 <class 'float'>
# 11320 39.0 <class 'float'>
# 11321 33.0 <class 'float'>
# 11322 24.0 <class 'float'>
# 11323 30.0 <class 'float'>
# 11324 20.0 <class 'float'>
# 11325 28.0 <class 'float'>
# 11326 30.0 <class 'float'>
# 11327 39.0 <class 'float'>
# 11328 42.0 <class 'float'>
# 11329 20.0 <class 'float'>
# 11330 23.0 <class 'float'>
# 11331 21.0 <class 'float'>
# 11332 20.0 <class 'float'>
# 11333 25.0 <class 'float'>
# 11334 27.0 <class 'float'>
# 11335 22.0 <class 'float'>
# 11336 39.0 <class 'float'>
# 11337 24.0 <class 'float'>
# 11338 32.0 <class 'float'>
# 11339 30.0 <class 'float'>
# 11340 28.0 <class 'float'>
# 11341 28.0 <class 'float'>
# 11342 45.0 <class 'float'>
# 11343 32.0 <class 'float'>
# 11344 27.0 <class 'float'>
# 11345 46.0 <class 'float'>
# 11346 28.0 <class 'float'>
# 11347 27.0 <class 'float'>
# 11348 31.0 <class 'float'>
# 11349 28.0 <class 'float'>
# 11350 48.0 <class 'float'>
# 11351 32.0 <class 'float'>
# 11352 27.0 <class 'float'>
# 11353 39.0 <class 'float'>
# 11354 43.0 <class 'float'>
# 11355 33.0 <class 'float'>
# 11356 32.0 <class 'float'>
# 11357 22.0 <class 'float'>
# 11358 25.0 <class 'float'>
# 11359 32.0 <class 'float'>
# 11360 26.0 <class 'float'>
# 11361 32.0 <class 'float'>
# 11362 26.0 <class 'float'>
# 11363 25.0 <class 'float'>
# 11364 43.0 <class 'float'>
# 11365 33.0 <class 'float'>
# 11366 28.0 <class 'float'>
# 11367 35.0 <class 'float'>
# 11368 26.0 <class 'float'>
# 11369 24.0 <class 'float'>
# 11370 23.0 <class 'float'>
# 11371 28.0 <class 'float'>
# 11372 50.0 <class 'float'>
# 11373 50.0 <class 'float'>
# 11374 25.0 <class 'float'>
# 11375 41.0 <class 'float'>
# 11376 35.0 <class 'float'>
# 11377 35.0 <class 'float'>
# 11378 22.0 <class 'float'>
# 11379 31.0 <class 'float'>
# 11380 21.0 <class 'float'>
# 11381 29.0 <class 'float'>
# 11382 27.0 <class 'float'>
# 11383 33.0 <class 'float'>
# 11384 31.0 <class 'float'>
# 11385 32.0 <class 'float'>
# 11386 25.0 <class 'float'>
# 11387 28.0 <class 'float'>
# 11388 26.0 <class 'float'>
# 11389 26.0 <class 'float'>
# 11390 26.0 <class 'float'>
# 11391 32.0 <class 'float'>
# 11392 32.0 <class 'float'>
# 11393 36.0 <class 'float'>
# 11394 25.0 <class 'float'>
# 11395 34.0 <class 'float'>
# 11396 25.0 <class 'float'>
# 11397 30.0 <class 'float'>

# %%
count, bin_edges = np.histogram(df['Age'])

df['Age'].plot(kind='hist', xticks=bin_edges)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/wsuser/ipykernel_749/3288429880.py in <module>
# ----> 1 count, bin_edges = np.histogram(df['Age'])
#       2
#       3 df['Age'].plot(kind='hist', xticks=bin_edges)
#       4
#       5 plt.show()
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     321         first_edge, last_edge = a.min(), a.max()
#     322         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323             raise ValueError(
#     324                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     325
#
# ValueError: autodetected range of [nan, nan] is not finite

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
